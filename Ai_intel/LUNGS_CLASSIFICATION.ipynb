# %% [markdown]
# # ***PLAN***
#
#
# 1.   Get All DATA
#
# 2.   Check data available to us
#
#
#
#
# 3.   Plot some data and check the suitable convulation filters
#
# 4.   Convert all data and labels to arrays and also apply filters
#
# 5.   Plot some Data
#
#
# 6.   Initialise model
#
# 7.   Train Model on Vgg16 or Resnet
#
# 8.   test model and find accuracy and also apply filters on testing data while testing

# %% [markdown]
# # Step 1 Getting All Data

# %%
# !pip install kaggle
# !kaggle datasets download -d tolgadincer/labeled-chest-xray-images
# Out:
# ...
# 100% 1.17G/1.17G [00:22<00:00, 65.0MB/s]
# 100% 1.17G/1.17G [00:22<00:00, 56.3MB/s]

# %%
# !pwd
# Out:
# /content

# %%
# !unzip '/content/labeled-chest-xray-images.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: chest_xray/train/NORMAL/NORMAL-2558319-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2559035-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2559035-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2565226-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2568157-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2597757-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2597757-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-263932-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2646645-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2646923-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2655558-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2659844-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2675017-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2675017-0002.jpeg
# ...

# %%
pwd
# Out:
# '/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray'

# %%
# cp -r /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/chest_xray/__MACOSX/chest_xray/train/NORMAL/. /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/train/Normal

# %%
cd /content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection
# Out:
# /content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection

# %%
from google.colab import files
files.upload() #upload kaggle.json

# !pip install -q kaggle --upgrade
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-4ee22503-50e8-4931-850d-9634bfe61e94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ee22503-50e8-4931-850d-9634bfe61e94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# kaggle.json

# %%
# !unzip '/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest-xray-pneumonia.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: chest_xray/train/NORMAL/IM-0435-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0437-0001-0002.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0437-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0438-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0439-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0440-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0441-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0442-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0444-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0445-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0446-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0447-0001.jpeg
#   inflating: chest_xray/train/NORMAL/IM-0448-0001.jpeg
# ...

# %%
# cp -r /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/chest_xray/train/NORMAL/. /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/train/Normal

# %%
# CHECKING TOTAL PICS


# -----NORMAL PICS-----
import os
# list = os.listdir('/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train/Normal') # dir is your directory path
list = os.listdir('/content/chest_xray/train/NORMAL')
Normal_file1 = len(list)
print(Normal_file1,':Number of Normal Pics')


# -----Pneumonia PICS-----

l2 = os.listdir('/content/chest_xray/train/PNEUMONIA')
# it lists all directories 
pn2 = len(l2)
print(pn2,':Number of Pneumonia Pics')
# Out:
# 1349 :Number of Normal Pics
# 3883 :Number of Pneumonia Pics

# %%
# rm -r /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/train/Normal/nm

# %%
# rm -r /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/chest_xray

# %%
cd /content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/
# Out:
# [Errno 2] No such file or directory: '/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/'
# /content

# %%
! pip install -q kaggle

# %%
cd ..
# Out:
# /

# %%
! touch /root/.kaggle/kaggle.json

# %%
# !cd ~/.kaggle

# %%
cd /content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/
# Out:
# /content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray

# %%
import kaggle
# !echo '{"username":"oizomdata","key":"KEY"}' > ~/.kaggle/kaggle.json
# !kaggle datasets download -d mmoreaux/environmental-sound-classification-50
# !kaggle competitions list --csv
# Out:
# 401 - Unauthorized

# %%
# !unzip '/content/chest-xray-covid19-pneumonia.zip'
# Out:
# unzip:  cannot find or open /content/chest-xray-covid19-pneumonia.zip, /content/chest-xray-covid19-pneumonia.zip.zip or /content/chest-xray-covid19-pneumonia.zip.ZIP.

# %%
# !cp -r /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/Data/test/PNEUMONIA/. /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/train/Pneumonia

# %%
rm -r /content/drive/Shared\ drives/Shared\ Drive/PYTHON/Lung_Detection/chest_xray/train/COVID19

# %% [markdown]
# # Check Data .. Images

# %%
## Check normal Xrays
import os
dir_of_normal = r'/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train/NORMAL'
# listdir lists all things in a directory
list_of_normal = os.listdir(dir_of_normal) # dir is your directory path
print(list_of_normal) # it has all lists of images/things present in directory 

Normal_file1 = len(list_of_normal) # so the length of directory will be equal to total images
print(Normal_file1,':Number of Normal Pics For Training')
# Out:
# ['IM-0115-0001.jpeg', 'IM-0117-0001.jpeg', 'IM-0119-0001.jpeg', 'IM-0122-0001.jpeg', 'IM-0125-0001.jpeg', 'IM-0127-0001.jpeg', 'IM-0128-0001.jpeg', 'IM-0129-0001.jpeg', 'IM-0131-0001.jpeg', 'IM-0133-0001.jpeg', 'IM-0135-0001.jpeg', 'IM-0137-0001.jpeg', 'IM-0140-0001.jpeg', 'IM-0141-0001.jpeg', 'IM-0143-0001.jpeg', 'IM-0145-0001.jpeg', 'IM-0147-0001.jpeg', 'IM-0149-0001.jpeg', 'IM-0151-0001.jpeg', 'IM-0152-0001.jpeg', 'IM-0154-0001.jpeg', 'IM-0156-0001.jpeg', 'IM-0158-0001.jpeg', 'IM-0160-0001.jpeg', 'IM-0162-0001.jpeg', 'IM-0164-0001.jpeg', 'IM-0166-0001.jpeg', 'IM-0168-0001.jpeg', 'IM-0170-0001.jpeg', 'IM-0172-0001.jpeg', 'IM-0176-0001.jpeg', 'IM-0177-0001.jpeg', 'IM-0178-0001.jpeg', 'IM-0180-0001.jpeg', 'IM-0182-0001.jpeg', 'IM-0183-0001.jpeg', 'IM-0185-0001.jpeg', 'IM-0187-0001.jpeg', 'IM-0189-0001.jpeg', 'IM-0191-0001.jpeg', 'IM-0193-0001.jpeg', 'IM-0195-0001.jpeg', 'IM-0199-0001.jpeg', 'IM-0201-0001.jpeg', 'IM-0203-0001.jpeg', 'IM-0205-0001.jpeg', 'IM-0206-0001.jpeg', 'IM-0207-0
# ...

# %%
### Lets Check  Pneumonia Xrays available to us
dir_of_pneumonia = r'/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train/PNEUMONIA'
# dir variable stores the location

# lets get list of things present inside of this directory
list_of_pneumonia = os.listdir(dir_of_pneumonia)
print(list_of_pneumonia)

# Find the number of images present
print(len(list_of_pneumonia),": Number of Pneumonia Images For Training")
# Out:
# ['person1000_bacteria_2931.jpeg', 'person1000_virus_1681.jpeg', 'person1001_bacteria_2932.jpeg', 'person1002_bacteria_2933.jpeg', 'person1003_bacteria_2934.jpeg', 'person1003_virus_1685.jpeg', 'person1004_bacteria_2935.jpeg', 'person1004_virus_1686.jpeg', 'person1005_bacteria_2936.jpeg', 'person1005_virus_1688.jpeg', 'person1006_bacteria_2937.jpeg', 'person1007_bacteria_2938.jpeg', 'person1007_virus_1690.jpeg', 'person1008_bacteria_2939.jpeg', 'person1008_virus_1691.jpeg', 'person1009_virus_1694.jpeg', 'person100_virus_184.jpeg', 'person1010_bacteria_2941.jpeg', 'person1010_virus_1695.jpeg', 'person1011_bacteria_2942.jpeg', 'person1012_bacteria_2943.jpeg', 'person1014_bacteria_2945.jpeg', 'person1015_virus_1701.jpeg', 'person1015_virus_1702.jpeg', 'person1016_bacteria_2947.jpeg', 'person1016_virus_1704.jpeg', 'person1017_bacteria_2948.jpeg', 'person1018_bacteria_2949.jpeg', 'person1018_virus_1706.jpeg', 'person1019_bacteria_2950.jpeg', 'person1019_virus_1707.jpeg', 'person1019_virus_
# ...

# %%
# Checking Total images respectively for training
print(Normal_file1,':Number of Normal Pics For Training')
print(len(list_of_pneumonia),": Number of Pneumonia Images For Training")
# Out:
# 1341 :Number of Normal Pics For Training
# 3875 : Number of Pneumonia Images For Training

# %% [markdown]
# # Check different convo filters

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

# making 2 variable to store directory of 3 images normal,pneumonia
one_normal_img_dir = r'/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train/NORMAL/IM-0115-0001.jpeg'
one_pneumonia_img_dir = r'/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train/PNEUMONIA/person1000_bacteria_2931.jpeg'

# loading the images
one_normal_img_not_resized = cv2.imread(one_normal_img_dir)
one_pneumonia_img_not_resized = cv2.imread(one_pneumonia_img_dir)

# As images are of different shapes so resizing them
one_normal_img = cv2.resize(one_normal_img_not_resized,(224,224))
one_pneumonia_img = cv2.resize(one_pneumonia_img_not_resized,(224,224))



# concating all 3 arrays into 1 for showing together
imgs_all_2 = cv2.hconcat([one_normal_img, one_pneumonia_img])
cv2_imshow(imgs_all_2)



## other method to show images
# cv2_imshow(one_normal_img)
# cv2.waitKey(0)


# cv2_imshow(one_pneumonia_img)
# cv2.waitKey(0)


# cv2_imshow(one_covid_img)
# cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224 at 0x7FC6A08D1668>

# %%
## making a filter
kernel_try1 = np.array((
    [-2, -2, 0],                   # first filter
    [-2, 1, 2],
    [0, 2, 2]), dtype="int")           
normal_img_convo_1 = cv2.filter2D(one_normal_img,-1,kernel_try1)  # applied covulation layer on normal image


# concating for good preview
normal_and_convo = cv2.hconcat([one_normal_img,normal_img_convo_1]) 
cv2_imshow(normal_and_convo)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224 at 0x7FC6A08D14E0>

# %%
# making new filter 
kernel_try2 = np.array((
    [0,-1,0],
    [-1,5,-1],     # new filter
    [0,-1,0]),dtype='int')

normal_img_convo_2 = cv2.filter2D(one_normal_img,-1,kernel_try2)

# concating normal and new normal xray with applied convo filter
normal_and_convo_2 = cv2.hconcat([one_normal_img,normal_img_convo_2])
cv2_imshow(normal_and_convo_2)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224 at 0x7FC6A08E4550>

# %%
# checking the same filter on normal and pneumonia image
kernel_try2 = np.array((
    [0,-1,0],
    [-1,5,-1],     #  filter
    [0,-1,0]),dtype='int')


#applied convo on 1 normal img
normal_img_convo_2 = cv2.filter2D(one_normal_img,-1,kernel_try2)  

# making a variable to store pneumonia img directory
one_pneumonia_img_dir = r'/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train/PNEUMONIA/person1000_bacteria_2931.jpeg'
pneumonia_img_not_resized = cv2.imread(one_pneumonia_img_dir) 

## we have to resize it as well for nice preview and checking of filter
pneumonia_img = cv2.resize(pneumonia_img_not_resized,(224,224))

## now applying filter on the image of pneumonia
pneumonia_img_convo_2 = cv2.filter2D(pneumonia_img,-1,kernel_try2)

## now concating both of them in horizontal view
normal_and_pneumonia_concatinated = cv2.hconcat((normal_img_convo_2,pneumonia_img_convo_2))

# showing the image of normal and pneumonia
cv2_imshow(normal_and_pneumonia_concatinated)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224 at 0x7FC6A08E7BA8>

# %%
# checking 2 same pneumonia images with and without a filter
pneumonia_and_pneumonia_convoapplied = cv2.hconcat((pneumonia_img,pneumonia_img_convo_2))
cv2_imshow(pneumonia_and_pneumonia_convoapplied)
# Out:
# <PIL.Image.Image image mode=RGB size=448x224 at 0x7FC6A08DF8D0>

# %%
## Sir I have A question: How we'll use the filter in model? .. if we've chosen a filter how to use it
#Not required. fitler is just to visulaize image if convoultion will be used

# %%
print(pneumonia_img)
# Out:
# [[[18 18 18]
#   [21 21 21]
#   [27 27 27]
#   ...
#   [ 8  8  8]
#   [ 3  3  3]
#   [ 1  1  1]]
#
#  [[19 19 19]
#   [24 24 24]
#   [27 27 27]
#   ...
#   [ 9  9  9]
#   [ 5  5  5]
#   [ 1  1  1]]
#
#  [[22 22 22]
#   [24 24 24]
#   [25 25 25]
#   ...
#   [10 10 10]
#   [ 6  6  6]
#   [ 1  1  1]]
#
#  ...
#
#  [[10 10 10]
#   [10 10 10]
#   [ 8  8  8]
#   ...
#   [15 15 15]
#   [15 15 15]
#   [15 15 15]]
#
#  [[10 10 10]
#   [10 10 10]
#   [10 10 10]
#   ...
#   [15 15 15]
#   [15 15 15]
#   [15 15 15]]
#
#  [[10 10 10]
#   [10 10 10]
#   [10 10 10]
#   ...
#   [15 15 15]
#   [15 15 15]
#   [15 15 15]]]

# %% [markdown]
# # Making Model

# %%
#resize images as per INPUT_SHAPE

# %%
# 7 layer CNN simple
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=INPUT_SHAPE))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(Conv2D(250,(3,3)))
model.add(Activation("relu"))
  
model.add(Conv2D(128,(3,3)))
model.add(Activation("relu"))
model.add(AvgPool2D(2,2))
model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(AvgPool2D(2,2))

model.add(Conv2D(256,(2,2)))
model.add(Activation("relu"))
model.add(MaxPool2D(2,2))
    
model.add(Flatten())
model.add(Dense(32))
model.add(Dropout(0.25))
model.add(Dense(1))
model.add(Activation("sigmoid"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-30c941e814b1> in <module>()
#       1 # 7 layer CNN simple
# ----> 2 model = Sequential()
#       3 model.add(Conv2D(32, (3, 3), input_shape=INPUT_SHAPE))
#       4 model.add(Activation('relu'))
#       5 model.add(MaxPooling2D(pool_size=(2, 2)))
#
# NameError: name 'Sequential' is not defined

# %%
#train with parameters
#test 
#confusion matrix
#display test images

# %%
# from google.colab import files
# files.upload() #upload kaggle.json

# !pip install -q kaggle --upgrade
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json

# !kaggle kernels list 

# !kaggle competitions download -c DATASET

# !unzip -q train.csv.zip -d .
# !unzip -q test.csv.zip -d .
# !ls
# Out:
#      <input type="file" id="files-c4d15b01-45b3-4bd7-bf04-975dc6089c5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4d15b01-45b3-4bd7-bf04-975dc6089c5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# kaggle.json

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing import image
from google.colab import files

# %matplotlib inline

# %%
model1 = tf.keras.models.Sequential([  ## initializing and making an empty model with sequential
  
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution layer
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)), ## image input shape is 300x300x3 
                           #16 neurons in this layer

    tf.keras.layers.MaxPooling2D(2, 2),   # doing max_pooling
  
    # The second convolution layer
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'), # another layer with 32 neurons
    tf.keras.layers.MaxPooling2D(2,2),   # doing max_pooling
  
    # The third convolution layer
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # another layer with 64 neurons
    tf.keras.layers.MaxPooling2D(2,2),      # doing max_pooling
  
    # The fourth convolution layer
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # another layer with 64 neurons
    tf.keras.layers.MaxPooling2D(2,2),        # doing max_pooling
  
    # The fifth convolution 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # another layer with 64 neurons
    tf.keras.layers.MaxPooling2D(2,2),        # doing max_pooling

  
    tf.keras.layers.Flatten(),  # reducing layers arrays

    tf.keras.layers.Dense(512, activation='relu'), # 512 neuron hidden layer



    # Only 1 output neuron. It will contain a value from 0-1 where 0 for ('normal') clas and 
    # 1 for ('pneumonia') class
    tf.keras.layers.Dense(1, activation='sigmoid')

])

# to get the summary of the model
model1.summary()  # summarising a model

# configure the model for traning by adding metrics
model1.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=0.001), metrics = ['accuracy']) # compiling model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 33, 33, 64)        36928
# ...

# %%
train_datagen = ImageDataGenerator(rescale = 1/255)  # rescalling all images in training

test_datagen = ImageDataGenerator(rescale = 1/255)   # rescalling all images in testing



my_train_path='/content/chest_xray/train'
my_test_path='/content/chest_xray/test'

train_generator = train_datagen.flow_from_directory( 
    
# train_datagen.flow_from_directory goes through the directory finds all images , resize them into given 
# batch size ie 300,300 and class mode  binary for images and can be called for all images 
# after running also tells the number of images it has found

    my_train_path,
    target_size = (300,300),
    batch_size = 109,
    class_mode = 'binary',
   
)

validation_generator = test_datagen.flow_from_directory(
    
    
# test_datagen.flow_from_directory goes through the directory finds all images , resize them into given 
# batch size ie 300,300 and class mode  binary for images and can be called for all images 
# after running also tells the number of images it has found


    my_test_path,
    target_size = (300, 300),
    batch_size = 13,
    class_mode = 'binary')
    

# checkpoint
filepath="weights.best1.hdf5" # mentioning a file for saving checkpoint model in case it gets interrupted

checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
## we marked filepath, monitor and mentioned to save best model only 


callbacks_list = [checkpoint]  # customising model to save checkpoints

# training the model
history1 = model1.fit( # training model
    train_generator,  # it has all images
    steps_per_epoch = 2,  # steps per epoch
    epochs = 12,
    callbacks=callbacks_list,
    validation_data = validation_generator
)
# Out:
# Found 5232 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/12
# 2/2 [==============================] - ETA: 0s - loss: 1.3660 - accuracy: 0.7523
# Epoch 00001: val_accuracy improved from -inf to 0.37500, saving model to weights.best1.hdf5
# 2/2 [==============================] - 8s 4s/step - loss: 1.3660 - accuracy: 0.7523 - val_loss: 0.7110 - val_accuracy: 0.3750
# Epoch 2/12
# 2/2 [==============================] - ETA: 0s - loss: 0.6694 - accuracy: 0.4954
# Epoch 00002: val_accuracy improved from 0.37500 to 0.62500, saving model to weights.best1.hdf5
# 2/2 [==============================] - 9s 4s/step - loss: 0.6694 - accuracy: 0.4954 - val_loss: 0.8349 - val_accuracy: 0.6250
# Epoch 3/12
# 2/2 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.7339
# Epoch 00003: val_accuracy did not improve from 0.62500
# ...

# %%
# load new unseen dataset
eval_datagen = ImageDataGenerator(rescale = 1/255)  # normalize all images
test_generator = eval_datagen.flow_from_directory(   # making evaluation data
    '/content/chest_xray/test/',
    target_size = (300, 300),
    batch_size = 19, 
    class_mode = 'binary'
)

eval_result = model1.evaluate_generator(test_generator, 12)
print('loss rate at evaluation data :', eval_result[0])
print('accuracy rate at evaluation data :', eval_result[1])
# Out:
# Found 624 images belonging to 2 classes.
# WARNING:tensorflow:From <ipython-input-9-77cb1f78ee64>:10: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# loss rate at evaluation data : 0.3923386335372925
# accuracy rate at evaluation data : 0.8508771657943726

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load weights
model.load_weights("/content/weights.best_dropout.hdf5")
# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=0.001), metrics = ['accuracy'])
print("Created model and loaded weights from file")
# Out:
# Created model and loaded weights from file

# %%
# allow user to upload the image to predict
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  # predict images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(300,300))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis =0)

  images = np.vstack([x])
  classes = model1.predict(images, batch_size = 10)
  print(classes[0])
  if classes[0]> 0.5:  
     print(fn + ' is pneumonia')
     plt.imshow(img)
  else:
     print(fn + ' is normal')
     plt.imshow(img)
# Out:
#      <input type="file" id="files-bfacc706-378b-49cf-9584-40e23fb6d69d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfacc706-378b-49cf-9584-40e23fb6d69d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# Include the epoch in the file name (uses `str.format`)
import os
checkpoint_path = "training_2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
print(checkpoint_dir)
# Out:
# training_2

# %%
from keras.layers import Dropout

# %% [markdown]
# # B/W images based

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing import image
from google.colab import files

# %matplotlib inline

# %%
model = tf.keras.models.Sequential([  ## initializing and making an empty model with sequential
  
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution layer
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300,1)), ## image input shape is 300x300x3 
                           #16 neurons in this layer


    tf.keras.layers.MaxPooling2D(2,2),    # doing max_pooling
    tf.keras.layers.Dropout(0.2),

  
    # The second convolution layer
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'), # another layer with 32 neurons
    tf.keras.layers.MaxPooling2D(2,2),     # doing max_pooling
    tf.keras.layers.Dropout(0.2),


    # The third convolution layer
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # another layer with 64 neurons
    tf.keras.layers.MaxPooling2D(2,2),        # doing max_pooling
    tf.keras.layers.Dropout(0.2),



    # The fourth convolution layer
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # another layer with 64 neurons
    tf.keras.layers.MaxPooling2D(2,2),          # doing max_pooling
    tf.keras.layers.Dropout(0.2),  


    # The fifth convolution 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), # another layer with 64 neurons
    tf.keras.layers.MaxPooling2D(2,2),        # doing max_pooling
    tf.keras.layers.Dropout(0.2),



    tf.keras.layers.Flatten(),  # reducing layers arrays 
    tf.keras.layers.Dense(512, activation='relu'), # 512 neuron hidden layer



    # Only 1 output neuron. It will contain a value from 0-1 where 0 for ('normal') clas and 
    # 1 for ('pneumonia') class
    tf.keras.layers.Dense(1, activation='sigmoid')

])

# to get the summary of the model
model.summary()  # summarising a model

# configure the model for traning by adding metrics
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=0.001), metrics = ['accuracy']) # compiling model
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 298, 298, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        18496
# ...

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
#### my path based model

train_datagen = ImageDataGenerator(rescale = 1/255)  # rescalling all images in training
'''it can be 1./255 as well na?'''
test_datagen = ImageDataGenerator(rescale = 1/255)   # rescalling all images in testing



my_train_path='/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/train'
my_test_path='/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/test/'

train_generator = train_datagen.flow_from_directory( 
    
# train_datagen.flow_from_directory goes through the directory finds all images , resize them into given 
# batch size ie 300,300 and class mode  binary for images and can be called for all images 
# after running also tells the number of images it has found

    my_train_path,
    target_size = (300,300),
    batch_size = 109,
    class_mode = 'binary',
    color_mode = 'grayscale'
)

validation_generator = test_datagen.flow_from_directory(
    
    
# test_datagen.flow_from_directory goes through the directory finds all images , resize them into given 
# batch size ie 300,300 and class mode  binary for images and can be called for all images 
# after running also tells the number of images it has found


    my_test_path,
    target_size = (300, 224),
    batch_size = 13,
    class_mode = 'binary',
    color_mode = 'grayscale'
)

# checkpoint
filepath="weights.best.hdf5" # mentioning a file for saving checkpoint model in case it gets interrupted

checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
## we marked filepath, monitor and mentioned to save best model only 


callbacks_list = [checkpoint]  # customising model to save checkpoints

# training the model
history = model.fit( # training model
    train_generator,  # it has all images
    # steps_per_epoch = 2,  # steps per epoch
    steps_per_epoch = 4187//200,
    epochs = 12,            # 24 is hcf 
    callbacks=callbacks_list,
    validation_data = validation_generator,
    validation_steps = 4187//200
)
# Out:
# Found 4187 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/12
# 20/20 [==============================] - ETA: 0s - loss: 0.6644 - accuracy: 0.6335
# Epoch 00001: val_accuracy improved from -inf to 0.62692, saving model to weights.best.hdf5
# 20/20 [==============================] - 30s 1s/step - loss: 0.6644 - accuracy: 0.6335 - val_loss: 0.7390 - val_accuracy: 0.6269
# Epoch 2/12
# 20/20 [==============================] - ETA: 0s - loss: 0.6251 - accuracy: 0.6503
# Epoch 00002: val_accuracy did not improve from 0.62692
# 20/20 [==============================] - 29s 1s/step - loss: 0.6251 - accuracy: 0.6503 - val_loss: 0.7410 - val_accuracy: 0.4808
# Epoch 3/12
# 20/20 [==============================] - ETA: 0s - loss: 0.5171 - accuracy: 0.7844
# Epoch 00003: val_accuracy improved from 0.62692 to 0.73077, saving model to weights.best.hdf5
# ...

# %%
 # load weights
model.load_weights("/content/weights.best_dropout.hdf5")
# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=0.001), metrics = ['accuracy'])
print("Created model and loaded weights from file")
# Out:
# Created model and loaded weights from file

# %%
cd /content
# Out:
# /content

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  # predict images
  path = '/content/' + fn  
  # img = image.load_img(path, target_size=(300,300),grayscale=True)
  img = cv2.imread(path)
  img = cv2.cvtColor(img,cv2.cv2.COLOR_BGR2GRAY)
  img = cv2.resize(img,(300,300))
  

  x = image.img_to_array(img)
  x = np.expand_dims(x, axis =0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 10)
  print(classes[0])
  if classes[0]> 0.5:  #''' we could also had used np.argmax ?? then sliced through a list??''' 
    print(fn + ' is pneumonia')
    print('person is indected ')
    cv2_imshow(img)
    cv2.waitKey(0)
  else:
    print(fn + ' is normal')
    print('Persons lungs are totally great')
    print(' It isnt infected')
    cv2_imshow(img)
    cv2.waitKey(0)
    # print("pneumonia")
  # images is pneumonia 
  print(' imagse results are given')
  print('images results ares normal')
  print('results are pretty gre8')
# Out:
#      <input type="file" id="files-0956c470-c7f2-4af3-bac5-12d7cb308598" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0956c470-c7f2-4af3-bac5-12d7cb308598">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BACTERIA-1135262-0001.jpeg to BACTERIA-1135262-0001.jpeg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-80ac6b495da8> in <module>()
#      17
#      18   images = np.vstack([x])
# ---> 19   classes = model.predict(images, batch_size = 10)
#      20   print(classes[0])
#      21   if classes[0]> 0.5:  #''' we could also had used np.argmax ?? then sliced through a list??'''
#
# NameError: name 'model' is not defined

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/test/NORMAL/IM-0001-0001.jpeg')
img = cv2.cvtColor(img,cv2.cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(300,300))
from keras.preprocessing import image

x = image.img_to_array(img)
x = np.expand_dims(x, axis =0)

images = np.vstack([x])



classes = model.predict(images, batch_size = 10)
print(classes[0])
if classes[0]> 0.5:  #''' we could also had used np.argmax ?? then sliced through a list??''' 
    printf('is pneumonia')
    cv2_imshow(img)
    cv2.waitKey(0)
else:
    print('is normal')
    cv2_imshow(img)
    cv2.waitKey(0)
    print('Person isnt infected . It has no problem')
# Out:
# [0.]
# is normal
# <PIL.Image.Image image mode=L size=300x300 at 0x7F008C517A20>

# %%
path='/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/test/PNEUMONIA/person100_bacteria_477.jpeg'
img = cv2.imread(path)
img = cv2.cvtColor(img,cv2.cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(300,300))
  

x = image.img_to_array(img)
x = np.expand_dims(x, axis =0)

images = np.vstack([x])
classes = model.predict(images, batch_size = 10)
print(classes[0])
if classes[0]> 0.5:   
    print(' is pneumonia')
    print('Result')
    cv2_imshow(img)
    cv2.waitKey(0)
else:
    print(' is normal')
    cv2_imshow(img)
    print('Result is Given ')
    cv2.waitKey(0)
# Out:
# [1.]
#  is pneumonia
# Result
# <PIL.Image.Image image mode=L size=300x300 at 0x7EFFF4EFD208>

# %%
# load new unseen dataset
eval_datagen = ImageDataGenerator(rescale = 1/255)

test_generator = eval_datagen.flow_from_directory(
    '/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/test',
    target_size = (300, 300),
    batch_size = 19, 
    class_mode = 'binary',
    color_mode = 'grayscale'
)

eval_result = model.evaluate_generator(test_generator)
print('loss rate at evaluation data :', eval_result[0])
print('accuracy rate at evaluation data :', eval_result[1])
# Out:
# Found 624 images belonging to 2 classes.
# WARNING:tensorflow:From <ipython-input-23-a381cb685190>:12: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# loss rate at evaluation data : 0.3277793228626251
# accuracy rate at evaluation data : 0.8782051205635071

# %%
# Model trained on grayscale

fig, ax = plt.subplots(figsize = (8,6))
ax.plot(history.history["loss"], label = "training_loss")
ax.plot(history.history["val_loss"], label = "val_loss")
plt.xlabel("epochs")
plt.ylabel("loss function")
ax.legend(loc = 'upper right', shadow = True,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b51fe6462485> in <module>()
#       2
#       3 fig, ax = plt.subplots(figsize = (8,6))
# ----> 4 ax.plot(history.history["loss"], label = "training_loss")
#       5 ax.plot(history.history["val_loss"], label = "val_loss")
#       6 plt.xlabel("epochs")
#
# NameError: name 'history' is not defined

# %%
print()
# Out:
# 0

# %%
 # load weights
model.load_weights("/content/weights.best_dropout.hdf5")
# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=0.001), metrics = ['accuracy'])
print("Created model and loaded weights from file")
# Out:
# Created model and loaded weights from file

# %%
from sklearn.metrics import classification_report,confusion_matrix
import numpy as np
import pandas as pd

# load new unseen dataset
eval_datagen = ImageDataGenerator(rescale = 1/255)

test_generator = eval_datagen.flow_from_directory(
    '/content/drive/Shared drives/Shared Drive/PYTHON/Lung_Detection/chest_xray/test',
    target_size = (300, 300),
    batch_size = 19, 
    class_mode = 'binary',
    color_mode = 'grayscale'
    
)
# Out:
# Found 624 images belonging to 2 classes.

# %%
Y_pred = model.predict(test_generator)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-054b9d60da8e> in <module>()
# ----> 1 Y_pred = model.predict(test_generator)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
# ...

# %%
def corrector(x):
  list_of_val = []
  for i in x:
    if i<0.5:
      list_of_val.append(0.)
    else:
      list_of_val.append(1.)
  list_of_val = np.array(list_of_val)
  return list_of_val

print(corrector(Y_pred))


# new = []

# for i in Y_pred:
#   if i<0.5:
#     new.append(0.)
#   else:
#     new.append(1.)

# print(new)


# print(corrector(Y_pred))

# %%
print(np.round(Y_pred))

# %%
# Y_pred = np.argmax(Y_pred,axis=0)

print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, corrector(Y_pred)))
print('Classification Report')
# Out:
# Confusion Matrix
# [[ 85 149]
#  [115 275]]
# Classification Report

# %%
predictions = model.predict(test_generator)

# Get most likely class
predicted_classes = corrector(predictions)
print(classification_report(test_generator.classes, predicted_classes, target_names = ['Normal',
                                                                                       'Pneumonia']))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.41      0.35      0.38       234
#    Pneumonia       0.64      0.70      0.67       390
#
#     accuracy                           0.57       624
#    macro avg       0.53      0.53      0.53       624
# weighted avg       0.56      0.57      0.56       624

# %%
from ipywidgets import widgets
from ipywidgets import interact

# %%
from google.colab import files
uploaded = files.upload()

def f(a, b, c):
  for fn in uploaded.keys():
    # predict images
    path = '/content/' + fn
    img = image.load_img(path, target_size=(300,300))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis =0)

    images = np.vstack([x])
    classes = model1.predict(images, batch_size = 10)
    print(classes[0])
    if classes[0]> 0.5:  
      print(fn + ' is pneumonia')
      plt.imshow(img)
    else:
      print(fn + ' is normal')
      plt.imshow(img)
      print('{}*{}*{}={}'.format(a, b, c, a*b*c))

out = widgets.interactive_output(f, {'a': a, 'b': b, 'c': c})

widgets.HBox([widgets.VBox([a, b, c]), out])

# %%
def f(x):
  return x
interact(f, x=widgets.Combobox(options=["Chicago", "New York", "Washington"], value="Chicago"))
# Out:
# interactive(children=(Combobox(value='Chicago', description='x', options=('Chicago', 'New York', 'Washington')…
# <function __main__.f>

# %%
from ipywidgets import FileUpload
upload = FileUpload(multiple=False,)
upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
import io
from PIL import Image

for name, file_info in upload.value.items():
    img = Image.open(io.BytesIO(file_info['content']))
    
img = np.array(img)
import cv2
from google.colab.patches import cv2_imshow
cv2_imshow(img)

# %%
from flask import Flask, render_template, request, session, redirect, url_for, flash
import os
from werkzeug.utils import secure_filename
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import cv2
import numpy as np

UPLOAD_FOLDER = './flask app/assets/images'
ALLOWED_EXTENSIONS = set(['png', 'jpg', 'jpeg', 'gif'])
# Create Database if it doesnt exist

app = Flask(__name__,static_url_path='/assets',
            static_folder='./flask app/assets', 
            template_folder='./flask app')
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER


@app.route('/')
def root():
   return render_template('index.html')

@app.route('/index.html')
def index():
   return render_template('index.html')

@app.route('/contact.html')
def contact():
   return render_template('contact.html')

@app.route('/news.html')
def news():
   return render_template('news.html')

@app.route('/about.html')
def about():
   return render_template('about.html')

@app.route('/faqs.html')
def faqs():
   return render_template('faqs.html')

@app.route('/prevention.html')
def prevention():
   return render_template('prevention.html')

@app.route('/upload.html')
def upload():
   return render_template('upload.html')

@app.route('/upload_chest.html')
def upload_chest():
   return render_template('upload_chest.html')


@app.route('/upload_ct.html')
def upload_ct():
   return render_template('upload_ct.html')

@app.route('/uploaded_chest', methods = ['POST', 'GET'])
def uploaded_chest():
   if request.method == 'POST':
        # check if the post request has the file part
        if 'file' not in request.files:
            flash('No file part')
            return redirect(request.url)
        file = request.files['file']
        # if user does not select file, browser also
        # submit a empty part without filename
        if file.filename == '':
            flash('No selected file')
            return redirect(request.url)
        if file:
            # filename = secure_filename(file.filename)
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], 'upload_chest.jpg'))

   resnet_chest = load_model('models/resnet_chest.h5')
   vgg_chest = load_model('models/vgg_chest.h5')
   inception_chest = load_model('models/inceptionv3_chest.h5')
   xception_chest = load_model('models/xception_chest.h5')

   image = cv2.imread('./flask app/assets/images/upload_chest.jpg') # read file 
   image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
   image = cv2.resize(image,(224,224))
   image = np.array(image) / 255
   image = np.expand_dims(image, axis=0)
   
   resnet_pred = resnet_chest.predict(image)
   probability = resnet_pred[0]
   print("Resnet Predictions:")
   if probability[0] > 0.5:
      resnet_chest_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      resnet_chest_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(resnet_chest_pred)

   vgg_pred = vgg_chest.predict(image)
   probability = vgg_pred[0]
   print("VGG Predictions:")
   if probability[0] > 0.5:
      vgg_chest_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      vgg_chest_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(vgg_chest_pred)

   inception_pred = inception_chest.predict(image)
   probability = inception_pred[0]
   print("Inception Predictions:")
   if probability[0] > 0.5:
      inception_chest_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      inception_chest_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(inception_chest_pred)

   xception_pred = xception_chest.predict(image)
   probability = xception_pred[0]
   print("Xception Predictions:")
   if probability[0] > 0.5:
      xception_chest_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      xception_chest_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(xception_chest_pred)

   return render_template('results_chest.html',resnet_chest_pred=resnet_chest_pred,vgg_chest_pred=vgg_chest_pred,inception_chest_pred=inception_chest_pred,xception_chest_pred=xception_chest_pred)

@app.route('/uploaded_ct', methods = ['POST', 'GET'])
def uploaded_ct():
   if request.method == 'POST':
        # check if the post request has the file part
        if 'file' not in request.files:
            flash('No file part')
            return redirect(request.url)
        file = request.files['file']
        # if user does not select file, browser also
        # submit a empty part without filename
        if file.filename == '':
            flash('No selected file')
            return redirect(request.url)
        if file:
            # filename = secure_filename(file.filename)
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], 'upload_ct.jpg'))

   resnet_ct = load_model('models/resnet_ct.h5')
   vgg_ct = load_model('models/vgg_ct.h5')
   inception_ct = load_model('models/inception_ct.h5')
   xception_ct = load_model('models/xception_ct.h5')

   image = cv2.imread('./flask app/assets/images/upload_ct.jpg') # read file 
   image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
   image = cv2.resize(image,(224,224))
   image = np.array(image) / 255
   image = np.expand_dims(image, axis=0)
   
   resnet_pred = resnet_ct.predict(image)
   probability = resnet_pred[0]
   print("Resnet Predictions:")
   if probability[0] > 0.5:
      resnet_ct_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      resnet_ct_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(resnet_ct_pred)

   vgg_pred = vgg_ct.predict(image)
   probability = vgg_pred[0]
   print("VGG Predictions:")
   if probability[0] > 0.5:
      vgg_ct_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      vgg_ct_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(vgg_ct_pred)

   inception_pred = inception_ct.predict(image)
   probability = inception_pred[0]
   print("Inception Predictions:")
   if probability[0] > 0.5:
      inception_ct_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      inception_ct_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(inception_ct_pred)

   xception_pred = xception_ct.predict(image)
   probability = xception_pred[0]
   print("Xception Predictions:")
   if probability[0] > 0.5:
      xception_ct_pred = str('%.2f' % (probability[0]*100) + '% COVID') 
   else:
      xception_ct_pred = str('%.2f' % ((1-probability[0])*100) + '% NonCOVID')
   print(xception_ct_pred)

   return render_template('results_ct.html',resnet_ct_pred=resnet_ct_pred,vgg_ct_pred=vgg_ct_pred,inception_ct_pred=inception_ct_pred,xception_ct_pred=xception_ct_pred)

if __name__ == '__main__':
   app.secret_key = ".."
   app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
# !git clone https://github.com/mtobeiyf/keras-flask-deploy-webapp
# Out:
# Cloning into 'keras-flask-deploy-webapp'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 134 (delta 6), reused 5 (delta 2), pack-reused 117
# Receiving objects: 100% (134/134), 46.42 KiB | 11.61 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
cd keras-flask-deploy-webapp
# Out:
# /content/keras-flask-deploy-webapp

# %%
# !pip install -r requirements.txt
# !pip3 install --upgrade tensorflow keras
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/43/16/b07e3f7a4a024b47918f7018967eb984b0c542458a6141d8c48515aa81d4/tensorflow-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl
# ...
# Processing /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd/gast-0.2.2-cp36-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl
# ...
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
# ...

# %%
from tensorflow.keras.applications.imagenet_utils import preprocess_input, decode_predictions

# %%
from keras.applications.vgg16 import preprocess_input

# %%
from keras.applications.mobilenet_v2 import MobileNetV2
model = MobileNetV2(weights='imagenet')

# %%
MODEL_PATH = 'models/covid_attn_weights_best_vgg16.h5'

# %%
model = load_model(MODEL_PATH)
model._make_predict_function()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3c6011723bc5> in <module>()
# ----> 1 model = load_model(MODEL_PATH)
#       2 model._make_predict_function()
#
# NameError: name 'load_model' is not defined

# %%
img = img.resize((150, 150))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-56ffeb5cb402> in <module>()
# ----> 1 img = img.resize((150, 150))
#
# NameError: name 'img' is not defined
